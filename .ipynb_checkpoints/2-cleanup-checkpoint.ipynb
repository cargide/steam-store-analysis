# %% [markdown]
# # Cleaning the data
#
# ## 1) Joining
# At the moment, I have two different tables with the data, depending on their source, and I need to join them to have all the information in one dataframe

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
pd.set_option("max_columns", 100)

# %%
steam_app_data = pd.read_csv('data_backup/steam_app_data.csv') #Backup of the data created while the final version downloads
steam_app_data
# Out:
#      type                       name  steam_appid  required_age is_free  \
# 0    game             Counter-Strike           10           0.0   False
# 1    game      Team Fortress Classic           20           0.0   False
# 2    game              Day of Defeat           30           0.0   False
# 3    game         Deathmatch Classic           40           0.0   False
# 4    game  Half-Life: Opposing Force           50           0.0   False
# ..    ...                        ...          ...           ...     ...
# 995  game            Forza Horizon 5      1551360           0.0   False
# 996  game                 God of War      1593500          18.0   False
# 997  game                 Sabre Team      1627140           0.0   False
# 998  game          Vampire Survivors      1794680           0.0   False
# 999  game        Mirror 2: Project X      1832640           0.0   False
#
#     controller_support                                                dlc  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ..                 ...                                                ...
# 995               full  [1613284, 1648020, 1798680, 1613282, 1613285, ...
# 996               full                                                NaN
# 997                NaN                                                NaN
# 998               full                                                NaN
# 999                NaN  [1881490, 1858303, 1858305, 1867630, 1858300, ...
#
#                                   detailed_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  <h1>Forza Horizon 5 Version Comparison</h1><p>...
# 996  <strong>Enter the Norse realm</strong><br>His ...
# 997  <strong>Who Dares Wins</strong><br><br>The Spe...
# 998  Vampire Survivors is currently a time survival...
# 999  Please know that the release version of the Ea...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  Your Ultimate Horizon Adventure awaits! Explor...
# 996  <strong>Enter the Norse realm</strong><br>His ...
# 997  <strong>Who Dares Wins</strong><br><br>The Spe...
# 998  Vampire Survivors is currently a time survival...
# 999  Please know that the release version of the Ea...
#
#                                      short_description  ...  \
# 0    Play the world's number 1 online action game. ...  ...
# 1    One of the most popular online action games of...  ...
# 2    Enlist in an intense brand of Axis vs. Allied ...  ...
# 3    Enjoy fast-paced multiplayer gaming with Death...  ...
# 4    Return to the Black Mesa Research Facility as ...  ...
# ..                                                 ...  ...
# 995  Your Ultimate Horizon Adventure awaits! Explor...  ...
# 996  His vengeance against the Gods of Olympus year...  ...
# 997  Sabre Team is an isometric squad-level turn-ba...  ...
# 998  Mow thousands of night creatures and survive u...  ...
# 999  This is a story-driven game powered by Unreal ...  ...
#
#                                             categories  \
# 0    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4    [{'id': 2, 'description': 'Single-player'}, {'...
# ..                                                 ...
# 995  [{'id': 2, 'description': 'Single-player'}, {'...
# 996  [{'id': 2, 'description': 'Single-player'}, {'...
# 997        [{'id': 2, 'description': 'Single-player'}]
# 998  [{'id': 2, 'description': 'Single-player'}, {'...
# 999  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                 genres  \
# 0               [{'id': '1', 'description': 'Action'}]
# 1               [{'id': '1', 'description': 'Action'}]
# 2               [{'id': '1', 'description': 'Action'}]
# 3               [{'id': '1', 'description': 'Action'}]
# 4               [{'id': '1', 'description': 'Action'}]
# ..                                                 ...
# 995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 996  [{'id': '1', 'description': 'Action'}, {'id': ...
# 997  [{'id': '3', 'description': 'RPG'}, {'id': '2'...
# 998  [{'id': '1', 'description': 'Action'}, {'id': ...
# 999  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                            screenshots  \
# 0    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ..                                                 ...
# 995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 996  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 997  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 998  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                 movies    recommendations  \
# 0                                                  NaN  {'total': 118421}
# 1                                                  NaN    {'total': 4479}
# 2                                                  NaN    {'total': 3122}
# 3                                                  NaN    {'total': 1496}
# 4                                                  NaN   {'total': 11308}
# ..                                                 ...                ...
# 995  [{'id': 256859757, 'name': 'Forza Horizon 5 La...   {'total': 57234}
# 996  [{'id': 256864004, 'name': 'Features Trailer',...   {'total': 25326}
# 997  [{'id': 256837328, 'name': 'Trailer', 'thumbna...                NaN
# 998  [{'id': 256858285, 'name': 'Early Access', 'th...   {'total': 29584}
# 999  [{'id': 256870130, 'name': 'CG_montage-en', 't...   {'total': 24139}
#
#                                           achievements  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  {'total': 53, 'highlighted': [{'name': 'Welcom...
# 996  {'total': 37, 'highlighted': [{'name': 'Father...
# 997                                                NaN
# 998  {'total': 43, 'highlighted': [{'name': 'Wings'...
# 999  {'total': 1, 'highlighted': [{'name': 'Heros o...
#
#                                        release_date  \
# 0     {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1     {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2     {'coming_soon': False, 'date': '1 May, 2003'}
# 3     {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4     {'coming_soon': False, 'date': '1 Nov, 1999'}
# ..                                              ...
# 995   {'coming_soon': False, 'date': '8 Nov, 2021'}
# 996  {'coming_soon': False, 'date': '14 Jan, 2022'}
# 997   {'coming_soon': False, 'date': '4 Jun, 2021'}
# 998  {'coming_soon': False, 'date': '17 Dec, 2021'}
# 999  {'coming_soon': False, 'date': '20 Jan, 2022'}
#
#                                           support_info  \
# 0    {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                             {'url': '', 'email': ''}
# 2                             {'url': '', 'email': ''}
# 3                             {'url': '', 'email': ''}
# 4    {'url': 'https://help.steampowered.com', 'emai...
# ..                                                 ...
# 995  {'url': 'https://support.forzamotorsport.net/'...
# 996  {'url': 'https://support.sms.playstation.com/h...
# 997  {'url': 'https://www.ziggurat.games/contact', ...
# 998         {'url': '', 'email': 'support@poncle.net'}
# 999       {'url': '', 'email': 'support@mirror-2.com'}
#
#                                             background  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...
# ..                                                 ...
# 995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                    content_descriptors
# 0    {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1    {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                           {'ids': [], 'notes': None}
# 3                           {'ids': [], 'notes': None}
# 4                           {'ids': [], 'notes': None}
# ..                                                 ...
# 995                         {'ids': [], 'notes': None}
# 996  {'ids': [2, 5], 'notes': 'Gameplay consists of...
# 997                         {'ids': [], 'notes': None}
# 998                         {'ids': [], 'notes': None}
# 999                         {'ids': [], 'notes': None}
#
# [1000 rows x 39 columns]

# %%
steamspy_data = pd.read_csv('data_backup/steamspy_data.csv') #Backup of the data created while the final version downloads
steamspy_data
# Out:
#        appid                       name            developer  \
# 0         10             Counter-Strike                Valve
# 1         20      Team Fortress Classic                Valve
# 2         30              Day of Defeat                Valve
# 3         40         Deathmatch Classic                Valve
# 4         50  Half-Life: Opposing Force     Gearbox Software
# ..       ...                        ...                  ...
# 995  1551360            Forza Horizon 5     Playground Games
# 996  1593500                 God of War  Santa Monica Studio
# 997  1627140                 Sabre Team    Krisalis Software
# 998  1794680          Vampire Survivors               poncle
# 999  1832640        Mirror 2: Project X       KAGAMI Ⅱ WORKs
#
#               publisher  score_rank  positive  negative  userscore  \
# 0                 Valve         NaN    192940      4936          0
# 1                 Valve         NaN      5409       895          0
# 2                 Valve         NaN      5000       555          0
# 3                 Valve         NaN      1852       412          0
# 4                 Valve         NaN     13243       661          0
# ..                  ...         ...       ...       ...        ...
# 995   Xbox Game Studios         NaN     53313      8359          0
# 996  PlayStation PC LLC         NaN     34394      1053          0
# 997            Ziggurat         NaN         0         1          0
# 998              poncle         NaN     29794       262          0
# 999              NIJICO         NaN     23871       590          0
#
#                        owners  average_forever  average_2weeks  \
# 0    10,000,000 .. 20,000,000            11368             157
# 1     5,000,000 .. 10,000,000              217              58
# 2     5,000,000 .. 10,000,000              469               0
# 3     5,000,000 .. 10,000,000              256               0
# 4     5,000,000 .. 10,000,000              370               0
# ..                        ...              ...             ...
# 995    1,000,000 .. 2,000,000             2806             355
# 996    1,000,000 .. 2,000,000             1188             620
# 997        100,000 .. 200,000                0               0
# 998    2,000,000 .. 5,000,000              583             487
# 999    1,000,000 .. 2,000,000              152             128
#
#      median_forever  median_2weeks  price  initialprice  discount  \
# 0               193             48    999           999         0
# 1                14             58    499           499         0
# 2                24              0    499           499         0
# 3                13              0    499           499         0
# 4               213              0    499           499         0
# ..              ...            ...    ...           ...       ...
# 995            1786            394   5999          5999         0
# 996            1092            524   4999          4999         0
# 997               0              0    699           699         0
# 998             610            479    299           299         0
# 999             144            103    199           199         0
#
#                                              languages  \
# 0    English, French, German, Italian, Spanish - Sp...
# 1    English, French, German, Italian, Spanish - Sp...
# 2    English, French, German, Italian, Spanish - Spain
# 3    English, French, German, Italian, Spanish - Sp...
# 4                      English, French, German, Korean
# ..                                                 ...
# 995  English, French, Italian, German, Spanish - Sp...
# 996  English, French, Italian, German, Spanish - Sp...
# 997  English, French, Italian, German, Spanish - Spain
# 998                                            English
# 999  Japanese, English, Simplified Chinese, Traditi...
#
#                                              genre    ccu  \
# 0                                           Action  17108
# 1                                           Action    114
# 2                                           Action    157
# 3                                           Action      5
# 4                                           Action    157
# ..                                             ...    ...
# 995  Action, Adventure, Racing, Simulation, Sports  16779
# 996                         Action, Adventure, RPG  23121
# 997                                  RPG, Strategy      0
# 998       Action, Casual, Indie, RPG, Early Access  60974
# 999            Adventure, Indie, RPG, Early Access   2545
#
#                                                   tags
# 0    {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1    {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2    {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3    {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4    {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...
# ..                                                 ...
# 995  {'Racing': 471, 'Open World': 364, 'Driving': ...
# 996  {'Action': 347, 'Adventure': 323, 'Story Rich'...
# 997  {'Turn-Based Tactics': 195, 'Military': 188, '...
# 998  {'Action Roguelike': 131, 'Pixel Graphics': 11...
# 999  {'RPG': 121, 'Anime': 117, '3D': 102, 'Match 3...
#
# [1000 rows x 20 columns]

# %% [markdown]
# The way both APIs are structured make some of the columns to be repeated between the tables, but other than that, the should be able to merge without issue.

# %%
data = pd.concat([steam_app_data, steamspy_data], axis=1)
data
# Out:
#      type                       name  steam_appid  required_age is_free  \
# 0    game             Counter-Strike           10           0.0   False
# 1    game      Team Fortress Classic           20           0.0   False
# 2    game              Day of Defeat           30           0.0   False
# 3    game         Deathmatch Classic           40           0.0   False
# 4    game  Half-Life: Opposing Force           50           0.0   False
# ..    ...                        ...          ...           ...     ...
# 995  game            Forza Horizon 5      1551360           0.0   False
# 996  game                 God of War      1593500          18.0   False
# 997  game                 Sabre Team      1627140           0.0   False
# 998  game          Vampire Survivors      1794680           0.0   False
# 999  game        Mirror 2: Project X      1832640           0.0   False
#
#     controller_support                                                dlc  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ..                 ...                                                ...
# 995               full  [1613284, 1648020, 1798680, 1613282, 1613285, ...
# 996               full                                                NaN
# 997                NaN                                                NaN
# 998               full                                                NaN
# 999                NaN  [1881490, 1858303, 1858305, 1867630, 1858300, ...
#
#                                   detailed_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  <h1>Forza Horizon 5 Version Comparison</h1><p>...
# 996  <strong>Enter the Norse realm</strong><br>His ...
# 997  <strong>Who Dares Wins</strong><br><br>The Spe...
# 998  Vampire Survivors is currently a time survival...
# 999  Please know that the release version of the Ea...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  Your Ultimate Horizon Adventure awaits! Explor...
# 996  <strong>Enter the Norse realm</strong><br>His ...
# 997  <strong>Who Dares Wins</strong><br><br>The Spe...
# 998  Vampire Survivors is currently a time survival...
# 999  Please know that the release version of the Ea...
#
#                                      short_description  fullgame  \
# 0    Play the world's number 1 online action game. ...       NaN
# 1    One of the most popular online action games of...       NaN
# 2    Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3    Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4    Return to the Black Mesa Research Facility as ...       NaN
# ..                                                 ...       ...
# 995  Your Ultimate Horizon Adventure awaits! Explor...       NaN
# 996  His vengeance against the Gods of Olympus year...       NaN
# 997  Sabre Team is an isometric squad-level turn-ba...       NaN
# 998  Mow thousands of night creatures and survive u...       NaN
# 999  This is a story-driven game powered by Unreal ...       NaN
#
#                                    supported_languages  \
# 0    English<strong>*</strong>, French<strong>*</st...
# 1    English, French, German, Italian, Spanish - Sp...
# 2    English, French, German, Italian, Spanish - Spain
# 3    English, French, German, Italian, Spanish - Sp...
# 4                      English, French, German, Korean
# ..                                                 ...
# 995  English<strong>*</strong>, French<strong>*</st...
# 996  English<strong>*</strong>, French<strong>*</st...
# 997  English, French, Italian, German, Spanish - Spain
# 998                                            English
# 999  Japanese<strong>*</strong>, English, Simplifie...
#
#                                           header_image  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...
# ..                                                 ...
# 995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                             website  \
# 0                               NaN
# 1                               NaN
# 2       http://www.dayofdefeat.com/
# 3                               NaN
# 4                               NaN
# ..                              ...
# 995  http://www.forzamotorsport.net
# 996                             NaN
# 997     https://www.ziggurat.games/
# 998                             NaN
# 999                             NaN
#
#                                        pc_requirements  \
# 0    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4    {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ..                                                 ...
# 995  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 997  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 999  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       mac_requirements  \
# 0    {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1    {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2    {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3    {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4    {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ..                                                 ...
# 995  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 997                                                 []
# 998                                                 []
# 999  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                     linux_requirements  \
# 0    {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 1    {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 2    {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 3    {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 4    {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# ..                                                 ...
# 995  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 997                                                 []
# 998                                                 []
# 999  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                           legal_notice drm_notice  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 995                                                NaN        NaN
# 996  <h2 class="bb_tag">PRIVACY POLICY</h2><a href=...        NaN
# 997                  2021 © Ziggurat Interactive, Inc.        NaN
# 998                                                NaN        NaN
# 999                                                NaN        NaN
#
#                            ext_user_account_notice               developers  \
# 0                                              NaN                ['Valve']
# 1                                              NaN                ['Valve']
# 2                                              NaN                ['Valve']
# 3                                              NaN                ['Valve']
# 4                                              NaN     ['Gearbox Software']
# ..                                             ...                      ...
# 995  Xbox Live (Supports Linking to Steam Account)     ['Playground Games']
# 996                                            NaN  ['Santa Monica Studio']
# 997                                            NaN    ['Krisalis Software']
# 998                                            NaN               ['poncle']
# 999                                            NaN       ['KAGAMI Ⅱ WORKs']
#
#                  publishers demos  \
# 0                 ['Valve']   NaN
# 1                 ['Valve']   NaN
# 2                 ['Valve']   NaN
# 3                 ['Valve']   NaN
# 4                 ['Valve']   NaN
# ..                      ...   ...
# 995   ['Xbox Game Studios']   NaN
# 996  ['PlayStation PC LLC']   NaN
# 997            ['Ziggurat']   NaN
# 998              ['poncle']   NaN
# 999              ['NIJICO']   NaN
#
#                                         price_overview  \
# 0    {'currency': 'EUR', 'initial': 819, 'final': 8...
# 1    {'currency': 'EUR', 'initial': 399, 'final': 3...
# 2    {'currency': 'EUR', 'initial': 399, 'final': 3...
# 3    {'currency': 'EUR', 'initial': 399, 'final': 3...
# 4    {'currency': 'EUR', 'initial': 399, 'final': 3...
# ..                                                 ...
# 995  {'currency': 'EUR', 'initial': 5999, 'final': ...
# 996  {'currency': 'EUR', 'initial': 4999, 'final': ...
# 997  {'currency': 'EUR', 'initial': 569, 'final': 5...
# 998  {'currency': 'EUR', 'initial': 239, 'final': 2...
# 999  {'currency': 'EUR', 'initial': 159, 'final': 1...
#
#                      packages  \
# 0                 [574941, 7]
# 1                        [29]
# 2                        [30]
# 3                        [31]
# 4                        [32]
# ..                        ...
# 995  [547831, 596608, 596609]
# 996                  [564166]
# 997                  [577704]
# 998                  [644402]
# 999                  [659252]
#
#                                         package_groups  \
# 0    [{'name': 'default', 'title': 'Buy Counter-Str...
# 1    [{'name': 'default', 'title': 'Buy Team Fortre...
# 2    [{'name': 'default', 'title': 'Buy Day of Defe...
# 3    [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4    [{'name': 'default', 'title': 'Buy Half-Life: ...
# ..                                                 ...
# 995  [{'name': 'default', 'title': 'Buy Forza Horiz...
# 996  [{'name': 'default', 'title': 'Buy God of War'...
# 997  [{'name': 'default', 'title': 'Buy Sabre Team'...
# 998  [{'name': 'default', 'title': 'Buy Vampire Sur...
# 999  [{'name': 'default', 'title': 'Buy Mirror 2: P...
#
#                                            platforms  \
# 0      {'windows': True, 'mac': True, 'linux': True}
# 1      {'windows': True, 'mac': True, 'linux': True}
# 2      {'windows': True, 'mac': True, 'linux': True}
# 3      {'windows': True, 'mac': True, 'linux': True}
# 4      {'windows': True, 'mac': True, 'linux': True}
# ..                                               ...
# 995  {'windows': True, 'mac': False, 'linux': False}
# 996  {'windows': True, 'mac': False, 'linux': False}
# 997  {'windows': True, 'mac': False, 'linux': False}
# 998   {'windows': True, 'mac': True, 'linux': False}
# 999  {'windows': True, 'mac': False, 'linux': False}
#
#                                             metacritic reviews  \
# 0    {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                  NaN     NaN
# 2    {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                  NaN     NaN
# 4                                                  NaN     NaN
# ..                                                 ...     ...
# 995                                                NaN     NaN
# 996  {'score': 93, 'url': 'https://www.metacritic.c...     NaN
# 997                                                NaN     NaN
# 998                                                NaN     NaN
# 999                                                NaN     NaN
#
#                                             categories  \
# 0    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4    [{'id': 2, 'description': 'Single-player'}, {'...
# ..                                                 ...
# 995  [{'id': 2, 'description': 'Single-player'}, {'...
# 996  [{'id': 2, 'description': 'Single-player'}, {'...
# 997        [{'id': 2, 'description': 'Single-player'}]
# 998  [{'id': 2, 'description': 'Single-player'}, {'...
# 999  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                 genres  \
# 0               [{'id': '1', 'description': 'Action'}]
# 1               [{'id': '1', 'description': 'Action'}]
# 2               [{'id': '1', 'description': 'Action'}]
# 3               [{'id': '1', 'description': 'Action'}]
# 4               [{'id': '1', 'description': 'Action'}]
# ..                                                 ...
# 995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 996  [{'id': '1', 'description': 'Action'}, {'id': ...
# 997  [{'id': '3', 'description': 'RPG'}, {'id': '2'...
# 998  [{'id': '1', 'description': 'Action'}, {'id': ...
# 999  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                            screenshots  \
# 0    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ..                                                 ...
# 995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 996  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 997  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 998  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                 movies    recommendations  \
# 0                                                  NaN  {'total': 118421}
# 1                                                  NaN    {'total': 4479}
# 2                                                  NaN    {'total': 3122}
# 3                                                  NaN    {'total': 1496}
# 4                                                  NaN   {'total': 11308}
# ..                                                 ...                ...
# 995  [{'id': 256859757, 'name': 'Forza Horizon 5 La...   {'total': 57234}
# 996  [{'id': 256864004, 'name': 'Features Trailer',...   {'total': 25326}
# 997  [{'id': 256837328, 'name': 'Trailer', 'thumbna...                NaN
# 998  [{'id': 256858285, 'name': 'Early Access', 'th...   {'total': 29584}
# 999  [{'id': 256870130, 'name': 'CG_montage-en', 't...   {'total': 24139}
#
#                                           achievements  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  {'total': 53, 'highlighted': [{'name': 'Welcom...
# 996  {'total': 37, 'highlighted': [{'name': 'Father...
# 997                                                NaN
# 998  {'total': 43, 'highlighted': [{'name': 'Wings'...
# 999  {'total': 1, 'highlighted': [{'name': 'Heros o...
#
#                                        release_date  \
# 0     {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1     {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2     {'coming_soon': False, 'date': '1 May, 2003'}
# 3     {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4     {'coming_soon': False, 'date': '1 Nov, 1999'}
# ..                                              ...
# 995   {'coming_soon': False, 'date': '8 Nov, 2021'}
# 996  {'coming_soon': False, 'date': '14 Jan, 2022'}
# 997   {'coming_soon': False, 'date': '4 Jun, 2021'}
# 998  {'coming_soon': False, 'date': '17 Dec, 2021'}
# 999  {'coming_soon': False, 'date': '20 Jan, 2022'}
#
#                                           support_info  \
# 0    {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                             {'url': '', 'email': ''}
# 2                             {'url': '', 'email': ''}
# 3                             {'url': '', 'email': ''}
# 4    {'url': 'https://help.steampowered.com', 'emai...
# ..                                                 ...
# 995  {'url': 'https://support.forzamotorsport.net/'...
# 996  {'url': 'https://support.sms.playstation.com/h...
# 997  {'url': 'https://www.ziggurat.games/contact', ...
# 998         {'url': '', 'email': 'support@poncle.net'}
# 999       {'url': '', 'email': 'support@mirror-2.com'}
#
#                                             background  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...
# ..                                                 ...
# 995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                    content_descriptors    appid  \
# 0    {'ids': [2, 5], 'notes': 'Includes intense vio...       10
# 1    {'ids': [2, 5], 'notes': 'Includes intense vio...       20
# 2                           {'ids': [], 'notes': None}       30
# 3                           {'ids': [], 'notes': None}       40
# 4                           {'ids': [], 'notes': None}       50
# ..                                                 ...      ...
# 995                         {'ids': [], 'notes': None}  1551360
# 996  {'ids': [2, 5], 'notes': 'Gameplay consists of...  1593500
# 997                         {'ids': [], 'notes': None}  1627140
# 998                         {'ids': [], 'notes': None}  1794680
# 999                         {'ids': [], 'notes': None}  1832640
#
#                           name            developer           publisher  \
# 0               Counter-Strike                Valve               Valve
# 1        Team Fortress Classic                Valve               Valve
# 2                Day of Defeat                Valve               Valve
# 3           Deathmatch Classic                Valve               Valve
# 4    Half-Life: Opposing Force     Gearbox Software               Valve
# ..                         ...                  ...                 ...
# 995            Forza Horizon 5     Playground Games   Xbox Game Studios
# 996                 God of War  Santa Monica Studio  PlayStation PC LLC
# 997                 Sabre Team    Krisalis Software            Ziggurat
# 998          Vampire Survivors               poncle              poncle
# 999        Mirror 2: Project X       KAGAMI Ⅱ WORKs              NIJICO
#
#      score_rank  positive  negative  userscore                    owners  \
# 0           NaN    192940      4936          0  10,000,000 .. 20,000,000
# 1           NaN      5409       895          0   5,000,000 .. 10,000,000
# 2           NaN      5000       555          0   5,000,000 .. 10,000,000
# 3           NaN      1852       412          0   5,000,000 .. 10,000,000
# 4           NaN     13243       661          0   5,000,000 .. 10,000,000
# ..          ...       ...       ...        ...                       ...
# 995         NaN     53313      8359          0    1,000,000 .. 2,000,000
# 996         NaN     34394      1053          0    1,000,000 .. 2,000,000
# 997         NaN         0         1          0        100,000 .. 200,000
# 998         NaN     29794       262          0    2,000,000 .. 5,000,000
# 999         NaN     23871       590          0    1,000,000 .. 2,000,000
#
#      average_forever  average_2weeks  median_forever  median_2weeks  price  \
# 0              11368             157             193             48    999
# 1                217              58              14             58    499
# 2                469               0              24              0    499
# 3                256               0              13              0    499
# 4                370               0             213              0    499
# ..               ...             ...             ...            ...    ...
# 995             2806             355            1786            394   5999
# 996             1188             620            1092            524   4999
# 997                0               0               0              0    699
# 998              583             487             610            479    299
# 999              152             128             144            103    199
#
#      initialprice  discount  \
# 0             999         0
# 1             499         0
# 2             499         0
# 3             499         0
# 4             499         0
# ..            ...       ...
# 995          5999         0
# 996          4999         0
# 997           699         0
# 998           299         0
# 999           199         0
#
#                                              languages  \
# 0    English, French, German, Italian, Spanish - Sp...
# 1    English, French, German, Italian, Spanish - Sp...
# 2    English, French, German, Italian, Spanish - Spain
# 3    English, French, German, Italian, Spanish - Sp...
# 4                      English, French, German, Korean
# ..                                                 ...
# 995  English, French, Italian, German, Spanish - Sp...
# 996  English, French, Italian, German, Spanish - Sp...
# 997  English, French, Italian, German, Spanish - Spain
# 998                                            English
# 999  Japanese, English, Simplified Chinese, Traditi...
#
#                                              genre    ccu  \
# 0                                           Action  17108
# 1                                           Action    114
# 2                                           Action    157
# 3                                           Action      5
# 4                                           Action    157
# ..                                             ...    ...
# 995  Action, Adventure, Racing, Simulation, Sports  16779
# 996                         Action, Adventure, RPG  23121
# 997                                  RPG, Strategy      0
# 998       Action, Casual, Indie, RPG, Early Access  60974
# 999            Adventure, Indie, RPG, Early Access   2545
#
#                                                   tags
# 0    {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1    {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2    {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3    {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4    {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...
# ..                                                 ...
# 995  {'Racing': 471, 'Open World': 364, 'Driving': ...
# 996  {'Action': 347, 'Adventure': 323, 'Story Rich'...
# 997  {'Turn-Based Tactics': 195, 'Military': 188, '...
# 998  {'Action Roguelike': 131, 'Pixel Graphics': 11...
# 999  {'RPG': 121, 'Anime': 117, '3D': 102, 'Match 3...
#
# [1000 rows x 59 columns]

# %% [markdown]
# ## 2) Removing columns
# Besides finding the duplicate columns, there are other columns (like the descriptions) that offer no value to me, so I will clean them from the table to make it lighter.
#
# First I will look at the columns with descriptions, images and the like:

# %%
cols_to_drop = ['detailed_description', 'about_the_game', 'short_description', 'header_image', 'website', 'pc_requirements',
               'mac_requirements', 'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
               'packages', 'package_groups', 'screenshots', 'movies', 'achievements', 'support_info', 'background']

# %%
data = data.drop(cols_to_drop, 1)
# Out:
# C:\Users\carlo\AppData\Local\Temp/ipykernel_7912/2885956291.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop(cols_to_drop, 1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7912/2885956291.py in <module>
# ----> 1 data = data.drop(cols_to_drop, 1)
#       2 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4212                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4213                 if errors == "raise" and labels_missing:
# -> 4214                     raise KeyError(f"{labels} not found in axis")
#    4215
#    4216             slicer = [slice(None)] * self.ndim
#
# KeyError: "['detailed_description' 'about_the_game' 'short_description'\n 'header_image' 'website' 'pc_requirements' 'mac_requirements'\n 'linux_requirements' 'legal_notice' 'drm_notice'\n 'ext_user_account_notice' 'packages' 'package_groups' 'screenshots'\n 'movies' 'achievements' 'support_info' 'background'] not found in axis"

# %%
data.head()
# Out:
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc  fullgame  \
# 0                NaN  NaN       NaN
# 1                NaN  NaN       NaN
# 2                NaN  NaN       NaN
# 3                NaN  NaN       NaN
# 4                NaN  NaN       NaN
#
#                                  supported_languages            developers  \
# 0  English<strong>*</strong>, French<strong>*</st...             ['Valve']
# 1  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 2  English, French, German, Italian, Spanish - Spain             ['Valve']
# 3  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 4                    English, French, German, Korean  ['Gearbox Software']
#
#   publishers demos                                     price_overview  \
# 0  ['Valve']   NaN  {'currency': 'EUR', 'initial': 819, 'final': 8...
# 1  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 2  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 3  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 4  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres    recommendations  \
# 0  [{'id': '1', 'description': 'Action'}]  {'total': 118421}
# 1  [{'id': '1', 'description': 'Action'}]    {'total': 4479}
# 2  [{'id': '1', 'description': 'Action'}]    {'total': 3122}
# 3  [{'id': '1', 'description': 'Action'}]    {'total': 1496}
# 4  [{'id': '1', 'description': 'Action'}]   {'total': 11308}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                  content_descriptors  appid  \
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...     10
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...     20
# 2                         {'ids': [], 'notes': None}     30
# 3                         {'ids': [], 'notes': None}     40
# 4                         {'ids': [], 'notes': None}     50
#
#                         name         developer publisher  score_rank  \
# 0             Counter-Strike             Valve     Valve         NaN
# 1      Team Fortress Classic             Valve     Valve         NaN
# 2              Day of Defeat             Valve     Valve         NaN
# 3         Deathmatch Classic             Valve     Valve         NaN
# 4  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    192940      4936          0  10,000,000 .. 20,000,000            11368
# 1      5409       895          0   5,000,000 .. 10,000,000              217
# 2      5000       555          0   5,000,000 .. 10,000,000              469
# 3      1852       412          0   5,000,000 .. 10,000,000              256
# 4     13243       661          0   5,000,000 .. 10,000,000              370
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0             157             193             48    999           999
# 1              58              14             58    499           499
# 2               0              24              0    499           499
# 3               0              13              0    499           499
# 4               0             213              0    499           499
#
#    discount                                          languages   genre    ccu  \
# 0         0  English, French, German, Italian, Spanish - Sp...  Action  17108
# 1         0  English, French, German, Italian, Spanish - Sp...  Action    114
# 2         0  English, French, German, Italian, Spanish - Spain  Action    157
# 3         0  English, French, German, Italian, Spanish - Sp...  Action      5
# 4         0                    English, French, German, Korean  Action    157
#
#                                                 tags
# 0  {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1  {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2  {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3  {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4  {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...

# %% [markdown]
# Now I will check the duplicates:
