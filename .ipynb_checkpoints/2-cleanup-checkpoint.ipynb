# %% [markdown]
# # Cleaning the data
#
# ## 1) Joining
# At the moment, I have two different tables with the data, depending on their source, and I need to join them to have all the information in one dataframe

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
pd.set_option("max_columns", 100)

# %%
steam_app_data = pd.read_csv('data/steam_app_data.csv') #Backup of the data created while the final version downloads
steam_app_data
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        type                                        name  steam_appid  \
# 0      game                              Counter-Strike           10
# 1      game                       Team Fortress Classic           20
# 2      game                               Day of Defeat           30
# 3      game                          Deathmatch Classic           40
# 4      game                   Half-Life: Opposing Force           50
# ...     ...                                         ...          ...
# 34995  game                                     Santhai      1812930
# 34996  game                               Virus at Home      1814060
# 34997  game  Nelson and the Magic Cauldron: The Journey      1816650
# 34998  game                                     Stickit      1828900
# 34999  game    Christmas Celebration With Sakuya Izayoi      1835060
#
#       required_age is_free controller_support  dlc  \
# 0                0   False                NaN  NaN
# 1                0   False                NaN  NaN
# 2                0   False                NaN  NaN
# 3                0   False                NaN  NaN
# 4                0   False                NaN  NaN
# ...            ...     ...                ...  ...
# 34995            0   False                NaN  NaN
# 34996            0   False                NaN  NaN
# 34997            0   False                NaN  NaN
# 34998            0   False                NaN  NaN
# 34999            0   False                NaN  NaN
#
#                                     detailed_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 34995  Santhai is a 2D side scrolling RPG game that a...
# 34996  <img src="https://cdn.cloudflare.steamstatic.c...
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...
# 34998  <strong>Now with Online Multiplayer and Online...
# 34999  <strong>This is a unofficial fangame of the To...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 34995  Santhai is a 2D side scrolling RPG game that a...
# 34996  <img src="https://cdn.cloudflare.steamstatic.c...
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...
# 34998  <strong>Now with Online Multiplayer and Online...
# 34999  <strong>This is a unofficial fangame of the To...
#
#                                        short_description  fullgame  \
# 0      Play the world's number 1 online action game. ...       NaN
# 1      One of the most popular online action games of...       NaN
# 2      Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3      Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4      Return to the Black Mesa Research Facility as ...       NaN
# ...                                                  ...       ...
# 34995  This is a legendary game. come back for everyo...       NaN
# 34996  Set in the distant future of 2024, Virus At Ho...       NaN
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...       NaN
# 34998  A game for those who can stick it, and stick t...       NaN
# 34999  Celebrate Christmas with Sakuya Izayoi from th...       NaN
#
#                                      supported_languages  \
# 0      English<strong>*</strong>, French<strong>*</st...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 34995                                      English, Thai
# 34996                                            English
# 34997  English<strong>*</strong>, German<strong>*</st...
# 34998  English<strong>*</strong><br><strong>*</strong...
# 34999                           English, Korean, Russian
#
#                                             header_image  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 34995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                  website  \
# 0                                    NaN
# 1                                    NaN
# 2            http://www.dayofdefeat.com/
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 34995  https://www.hardworkerstudio.com/
# 34996                                NaN
# 34997                                NaN
# 34998  https://www.reddit.com/r/stickit/
# 34999                                NaN
#
#                                          pc_requirements  \
# 0      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ...                                                  ...
# 34995  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 0      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ...                                                  ...
# 34995                                                 []
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999                                                 []
#
#                                       linux_requirements  \
# 0      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 1      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 2      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 3      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 4      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# ...                                                  ...
# 34995                                                 []
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997                                                 []
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999                                                 []
#
#                                             legal_notice drm_notice  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 34995                                                NaN        NaN
# 34996                                                NaN        NaN
# 34997  Copyright © 2021 Manuel Schenk Games - all rig...        NaN
# 34998                                                NaN        NaN
# 34999                               @Team Shanghai Alice        NaN
#
#       ext_user_account_notice                                   developers  \
# 0                         NaN                                    ['Valve']
# 1                         NaN                                    ['Valve']
# 2                         NaN                                    ['Valve']
# 3                         NaN                                    ['Valve']
# 4                         NaN                         ['Gearbox Software']
# ...                       ...                                          ...
# 34995      Hardworker Studio   ['Hardworker Studio', 'Rachan Neamprasert']
# 34996                     NaN                            ['Bogdan Padjen']
# 34997                     NaN                      ['Manuel Schenk Games']
# 34998                     NaN                                 ['Symfonim']
# 34999                     NaN                             ['Sigyaad Team']
#
#                    publishers demos  \
# 0                   ['Valve']   NaN
# 1                   ['Valve']   NaN
# 2                   ['Valve']   NaN
# 3                   ['Valve']   NaN
# 4                   ['Valve']   NaN
# ...                       ...   ...
# 34995  ['Rachan Neamprasert']   NaN
# 34996       ['Bogdan Padjen']   NaN
# 34997   ['Secret Item Games']   NaN
# 34998            ['Symfonim']   NaN
# 34999        ['Sigyaad Team']   NaN
#
#                                           price_overview     packages  \
# 0      {'currency': 'USD', 'initial': 999, 'final': 9...  [574941, 7]
# 1      {'currency': 'EUR', 'initial': 399, 'final': 3...         [29]
# 2      {'currency': 'EUR', 'initial': 399, 'final': 3...         [30]
# 3      {'currency': 'EUR', 'initial': 399, 'final': 3...         [31]
# 4      {'currency': 'EUR', 'initial': 399, 'final': 3...         [32]
# ...                                                  ...          ...
# 34995  {'currency': 'EUR', 'initial': 819, 'final': 8...     [651886]
# 34996  {'currency': 'EUR', 'initial': 159, 'final': 1...     [652302]
# 34997  {'currency': 'EUR', 'initial': 1249, 'final': ...     [653213]
# 34998  {'currency': 'EUR', 'initial': 399, 'final': 3...     [657844]
# 34999  {'currency': 'EUR', 'initial': 329, 'final': 3...     [660217]
#
#                                           package_groups  \
# 0      [{'name': 'default', 'title': 'Buy Counter-Str...
# 1      [{'name': 'default', 'title': 'Buy Team Fortre...
# 2      [{'name': 'default', 'title': 'Buy Day of Defe...
# 3      [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4      [{'name': 'default', 'title': 'Buy Half-Life: ...
# ...                                                  ...
# 34995  [{'name': 'default', 'title': 'Buy Santhai', '...
# 34996  [{'name': 'default', 'title': 'Buy Virus at Ho...
# 34997  [{'name': 'default', 'title': 'Buy Nelson and ...
# 34998  [{'name': 'default', 'title': 'Buy Stickit', '...
# 34999  [{'name': 'default', 'title': 'Buy Christmas C...
#
#                                              platforms  \
# 0        {'windows': True, 'mac': True, 'linux': True}
# 1        {'windows': True, 'mac': True, 'linux': True}
# 2        {'windows': True, 'mac': True, 'linux': True}
# 3        {'windows': True, 'mac': True, 'linux': True}
# 4        {'windows': True, 'mac': True, 'linux': True}
# ...                                                ...
# 34995  {'windows': True, 'mac': False, 'linux': False}
# 34996  {'windows': True, 'mac': False, 'linux': False}
# 34997  {'windows': True, 'mac': False, 'linux': False}
# 34998  {'windows': True, 'mac': False, 'linux': False}
# 34999  {'windows': True, 'mac': False, 'linux': False}
#
#                                               metacritic reviews  \
# 0      {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                    NaN     NaN
# 2      {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 34995                                                NaN     NaN
# 34996                                                NaN     NaN
# 34997                                                NaN     NaN
# 34998                                                NaN     NaN
# 34999                                                NaN     NaN
#
#                                               categories  \
# 0      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4      [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 34995        [{'id': 2, 'description': 'Single-player'}]
# 34996  [{'id': 2, 'description': 'Single-player'}, {'...
# 34997        [{'id': 2, 'description': 'Single-player'}]
# 34998  [{'id': 2, 'description': 'Single-player'}, {'...
# 34999        [{'id': 2, 'description': 'Single-player'}]
#
#                                                   genres  \
# 0                 [{'id': '1', 'description': 'Action'}]
# 1                 [{'id': '1', 'description': 'Action'}]
# 2                 [{'id': '1', 'description': 'Action'}]
# 3                 [{'id': '1', 'description': 'Action'}]
# 4                 [{'id': '1', 'description': 'Action'}]
# ...                                                  ...
# 34995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34996  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34997  [{'id': '25', 'description': 'Adventure'}, {'i...
# 34998  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34999             [{'id': '4', 'description': 'Casual'}]
#
#                                              screenshots  \
# 0      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                  ...
# 34995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34996  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34997  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34998  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies    recommendations  \
# 0                                                    NaN  {'total': 118444}
# 1                                                    NaN    {'total': 4478}
# 2                                                    NaN    {'total': 3122}
# 3                                                    NaN    {'total': 1494}
# 4                                                    NaN   {'total': 11316}
# ...                                                  ...                ...
# 34995  [{'id': 256865353, 'name': 'Santhai Trailer', ...                NaN
# 34996  [{'id': 256868971, 'name': 'Virus At Home - Ga...                NaN
# 34997  [{'id': 256859762, 'name': 'Nelson 2 Trailer E...                NaN
# 34998  [{'id': 256861428, 'name': 'Stickit Trailer', ...                NaN
# 34999                                                NaN                NaN
#
#                                             achievements  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34995  {'total': 20, 'highlighted': [{'name': 'First ...
# 34996  {'total': 16, 'highlighted': [{'name': 'Nation...
# 34997                                                NaN
# 34998  {'total': 28, 'highlighted': [{'name': 'The Go...
# 34999                                                NaN
#
#                                          release_date  \
# 0       {'coming_soon': False, 'date': 'Nov 1, 2000'}
# 1       {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2       {'coming_soon': False, 'date': '1 May, 2003'}
# 3       {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4       {'coming_soon': False, 'date': '1 Nov, 1999'}
# ...                                               ...
# 34995  {'coming_soon': False, 'date': '13 Jan, 2022'}
# 34996   {'coming_soon': False, 'date': '7 Jan, 2022'}
# 34997  {'coming_soon': False, 'date': '28 Jan, 2022'}
# 34998  {'coming_soon': False, 'date': '12 Dec, 2021'}
# 34999  {'coming_soon': False, 'date': '21 Dec, 2021'}
#
#                                             support_info  \
# 0      {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                               {'url': '', 'email': ''}
# 2                               {'url': '', 'email': ''}
# 3                               {'url': '', 'email': ''}
# 4      {'url': 'https://help.steampowered.com', 'emai...
# ...                                                  ...
# 34995  {'url': 'https://www.hardworkerstudio.com/', '...
# 34996     {'url': '', 'email': 'svetaplanina@gmail.com'}
# 34997  {'url': 'https://www.manuelschenk.de/', 'email...
# 34998         {'url': '', 'email': 'symfonim@gmail.com'}
# 34999          {'url': '', 'email': 'sigyaad@gmail.com'}
#
#                                               background  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 34995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      content_descriptors
# 0      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                             {'ids': [], 'notes': None}
# 3                             {'ids': [], 'notes': None}
# 4                             {'ids': [], 'notes': None}
# ...                                                  ...
# 34995                         {'ids': [], 'notes': None}
# 34996                         {'ids': [], 'notes': None}
# 34997                         {'ids': [], 'notes': None}
# 34998                         {'ids': [], 'notes': None}
# 34999                         {'ids': [], 'notes': None}
#
# [35000 rows x 39 columns]

# %%
steamspy_data = pd.read_csv('data/steamspy_data.csv') #Backup of the data created while the final version downloads
steamspy_data
# Out:
#          appid                                        name  \
# 0           10                              Counter-Strike
# 1           20                       Team Fortress Classic
# 2           30                               Day of Defeat
# 3           40                          Deathmatch Classic
# 4           50                   Half-Life: Opposing Force
# ...        ...                                         ...
# 34995  1812930                                     Santhai
# 34996  1814060                               Virus at Home
# 34997  1816650  Nelson and the Magic Cauldron: The Journey
# 34998  1828900                                     Stickit
# 34999  1835060    Christmas Celebration With Sakuya Izayoi
#
#                                    developer           publisher  score_rank  \
# 0                                      Valve               Valve         NaN
# 1                                      Valve               Valve         NaN
# 2                                      Valve               Valve         NaN
# 3                                      Valve               Valve         NaN
# 4                           Gearbox Software               Valve         NaN
# ...                                      ...                 ...         ...
# 34995  Hardworker Studio, Rachan Neamprasert  Rachan Neamprasert         NaN
# 34996                          Bogdan Padjen       Bogdan Padjen         NaN
# 34997                    Manuel Schenk Games   Secret Item Games         NaN
# 34998                               Symfonim            Symfonim         NaN
# 34999                           Sigyaad Team        Sigyaad Team         NaN
#
#        positive  negative  userscore                    owners  \
# 0        192940      4936          0  10,000,000 .. 20,000,000
# 1          5409       895          0   5,000,000 .. 10,000,000
# 2          5000       555          0   5,000,000 .. 10,000,000
# 3          1852       412          0   5,000,000 .. 10,000,000
# 4         13243       661          0   5,000,000 .. 10,000,000
# ...         ...       ...        ...                       ...
# 34995        50         9          0               0 .. 20,000
# 34996        19         2          0               0 .. 20,000
# 34997        21         2          0               0 .. 20,000
# 34998        30         0          0               0 .. 20,000
# 34999        74         5          0               0 .. 20,000
#
#        average_forever  average_2weeks  median_forever  median_2weeks   price  \
# 0                11368             157             193             48   999.0
# 1                  217              58              14             58   499.0
# 2                  469               0              24              0   499.0
# 3                  256               0              13              0   499.0
# 4                  370               0             213              0   499.0
# ...                ...             ...             ...            ...     ...
# 34995                0               0               0              0   999.0
# 34996                0               0               0              0   199.0
# 34997                0               0               0              0  1499.0
# 34998                0               0               0              0   499.0
# 34999                0               0               0              0   399.0
#
#        initialprice  discount  \
# 0             999.0       0.0
# 1             499.0       0.0
# 2             499.0       0.0
# 3             499.0       0.0
# 4             499.0       0.0
# ...             ...       ...
# 34995         999.0       0.0
# 34996         199.0       0.0
# 34997        1499.0       0.0
# 34998         499.0       0.0
# 34999         399.0       0.0
#
#                                                languages  \
# 0      English, French, German, Italian, Spanish - Sp...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 34995                                      English, Thai
# 34996                                            English
# 34997                                    English, German
# 34998                                            English
# 34999                           English, Korean, Russian
#
#                                            genre    ccu  \
# 0                                         Action  17108
# 1                                         Action    114
# 2                                         Action    157
# 3                                         Action      5
# 4                                         Action    157
# ...                                          ...    ...
# 34995  Action, Adventure, Indie, RPG, Simulation      5
# 34996                   Action, Adventure, Indie      1
# 34997                          Adventure, Casual      1
# 34998                   Action, Adventure, Indie      1
# 34999                                     Casual      3
#
#                                                     tags
# 0      {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1      {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2      {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3      {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4      {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...
# ...                                                  ...
# 34995  {'Adventure': 439, 'RPG': 434, 'Action': 430, ...
# 34996  {'FPS': 91, 'Action': 85, 'Shooter': 82, 'Horr...
# 34997  {'Adventure': 94, 'Point & Click': 88, 'Puzzle...
# 34998  {'Difficult': 452, 'Precision Platformer': 441...
# 34999  {'Anime': 51, 'Casual': 47, 'Relaxing': 44, 'C...
#
# [35000 rows x 20 columns]

# %% [markdown]
# The way both APIs are structured make some of the columns to be repeated between the tables, but other than that, the should be able to merge without issue.

# %%
data = pd.concat([steam_app_data, steamspy_data], axis=1)
data
# Out:
#        type                                        name  steam_appid  \
# 0      game                              Counter-Strike           10
# 1      game                       Team Fortress Classic           20
# 2      game                               Day of Defeat           30
# 3      game                          Deathmatch Classic           40
# 4      game                   Half-Life: Opposing Force           50
# ...     ...                                         ...          ...
# 34995  game                                     Santhai      1812930
# 34996  game                               Virus at Home      1814060
# 34997  game  Nelson and the Magic Cauldron: The Journey      1816650
# 34998  game                                     Stickit      1828900
# 34999  game    Christmas Celebration With Sakuya Izayoi      1835060
#
#       required_age is_free controller_support  dlc  \
# 0                0   False                NaN  NaN
# 1                0   False                NaN  NaN
# 2                0   False                NaN  NaN
# 3                0   False                NaN  NaN
# 4                0   False                NaN  NaN
# ...            ...     ...                ...  ...
# 34995            0   False                NaN  NaN
# 34996            0   False                NaN  NaN
# 34997            0   False                NaN  NaN
# 34998            0   False                NaN  NaN
# 34999            0   False                NaN  NaN
#
#                                     detailed_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 34995  Santhai is a 2D side scrolling RPG game that a...
# 34996  <img src="https://cdn.cloudflare.steamstatic.c...
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...
# 34998  <strong>Now with Online Multiplayer and Online...
# 34999  <strong>This is a unofficial fangame of the To...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 34995  Santhai is a 2D side scrolling RPG game that a...
# 34996  <img src="https://cdn.cloudflare.steamstatic.c...
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...
# 34998  <strong>Now with Online Multiplayer and Online...
# 34999  <strong>This is a unofficial fangame of the To...
#
#                                        short_description  fullgame  \
# 0      Play the world's number 1 online action game. ...       NaN
# 1      One of the most popular online action games of...       NaN
# 2      Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3      Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4      Return to the Black Mesa Research Facility as ...       NaN
# ...                                                  ...       ...
# 34995  This is a legendary game. come back for everyo...       NaN
# 34996  Set in the distant future of 2024, Virus At Ho...       NaN
# 34997  &quot;Nelson and the Magic Cauldron: The Journ...       NaN
# 34998  A game for those who can stick it, and stick t...       NaN
# 34999  Celebrate Christmas with Sakuya Izayoi from th...       NaN
#
#                                      supported_languages  \
# 0      English<strong>*</strong>, French<strong>*</st...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 34995                                      English, Thai
# 34996                                            English
# 34997  English<strong>*</strong>, German<strong>*</st...
# 34998  English<strong>*</strong><br><strong>*</strong...
# 34999                           English, Korean, Russian
#
#                                             header_image  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 34995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                  website  \
# 0                                    NaN
# 1                                    NaN
# 2            http://www.dayofdefeat.com/
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 34995  https://www.hardworkerstudio.com/
# 34996                                NaN
# 34997                                NaN
# 34998  https://www.reddit.com/r/stickit/
# 34999                                NaN
#
#                                          pc_requirements  \
# 0      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ...                                                  ...
# 34995  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 0      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ...                                                  ...
# 34995                                                 []
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999                                                 []
#
#                                       linux_requirements  \
# 0      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 1      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 2      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 3      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# 4      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
# ...                                                  ...
# 34995                                                 []
# 34996  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34997                                                 []
# 34998  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 34999                                                 []
#
#                                             legal_notice drm_notice  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 34995                                                NaN        NaN
# 34996                                                NaN        NaN
# 34997  Copyright © 2021 Manuel Schenk Games - all rig...        NaN
# 34998                                                NaN        NaN
# 34999                               @Team Shanghai Alice        NaN
#
#       ext_user_account_notice                                   developers  \
# 0                         NaN                                    ['Valve']
# 1                         NaN                                    ['Valve']
# 2                         NaN                                    ['Valve']
# 3                         NaN                                    ['Valve']
# 4                         NaN                         ['Gearbox Software']
# ...                       ...                                          ...
# 34995      Hardworker Studio   ['Hardworker Studio', 'Rachan Neamprasert']
# 34996                     NaN                            ['Bogdan Padjen']
# 34997                     NaN                      ['Manuel Schenk Games']
# 34998                     NaN                                 ['Symfonim']
# 34999                     NaN                             ['Sigyaad Team']
#
#                    publishers demos  \
# 0                   ['Valve']   NaN
# 1                   ['Valve']   NaN
# 2                   ['Valve']   NaN
# 3                   ['Valve']   NaN
# 4                   ['Valve']   NaN
# ...                       ...   ...
# 34995  ['Rachan Neamprasert']   NaN
# 34996       ['Bogdan Padjen']   NaN
# 34997   ['Secret Item Games']   NaN
# 34998            ['Symfonim']   NaN
# 34999        ['Sigyaad Team']   NaN
#
#                                           price_overview     packages  \
# 0      {'currency': 'USD', 'initial': 999, 'final': 9...  [574941, 7]
# 1      {'currency': 'EUR', 'initial': 399, 'final': 3...         [29]
# 2      {'currency': 'EUR', 'initial': 399, 'final': 3...         [30]
# 3      {'currency': 'EUR', 'initial': 399, 'final': 3...         [31]
# 4      {'currency': 'EUR', 'initial': 399, 'final': 3...         [32]
# ...                                                  ...          ...
# 34995  {'currency': 'EUR', 'initial': 819, 'final': 8...     [651886]
# 34996  {'currency': 'EUR', 'initial': 159, 'final': 1...     [652302]
# 34997  {'currency': 'EUR', 'initial': 1249, 'final': ...     [653213]
# 34998  {'currency': 'EUR', 'initial': 399, 'final': 3...     [657844]
# 34999  {'currency': 'EUR', 'initial': 329, 'final': 3...     [660217]
#
#                                           package_groups  \
# 0      [{'name': 'default', 'title': 'Buy Counter-Str...
# 1      [{'name': 'default', 'title': 'Buy Team Fortre...
# 2      [{'name': 'default', 'title': 'Buy Day of Defe...
# 3      [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4      [{'name': 'default', 'title': 'Buy Half-Life: ...
# ...                                                  ...
# 34995  [{'name': 'default', 'title': 'Buy Santhai', '...
# 34996  [{'name': 'default', 'title': 'Buy Virus at Ho...
# 34997  [{'name': 'default', 'title': 'Buy Nelson and ...
# 34998  [{'name': 'default', 'title': 'Buy Stickit', '...
# 34999  [{'name': 'default', 'title': 'Buy Christmas C...
#
#                                              platforms  \
# 0        {'windows': True, 'mac': True, 'linux': True}
# 1        {'windows': True, 'mac': True, 'linux': True}
# 2        {'windows': True, 'mac': True, 'linux': True}
# 3        {'windows': True, 'mac': True, 'linux': True}
# 4        {'windows': True, 'mac': True, 'linux': True}
# ...                                                ...
# 34995  {'windows': True, 'mac': False, 'linux': False}
# 34996  {'windows': True, 'mac': False, 'linux': False}
# 34997  {'windows': True, 'mac': False, 'linux': False}
# 34998  {'windows': True, 'mac': False, 'linux': False}
# 34999  {'windows': True, 'mac': False, 'linux': False}
#
#                                               metacritic reviews  \
# 0      {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                    NaN     NaN
# 2      {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 34995                                                NaN     NaN
# 34996                                                NaN     NaN
# 34997                                                NaN     NaN
# 34998                                                NaN     NaN
# 34999                                                NaN     NaN
#
#                                               categories  \
# 0      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4      [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 34995        [{'id': 2, 'description': 'Single-player'}]
# 34996  [{'id': 2, 'description': 'Single-player'}, {'...
# 34997        [{'id': 2, 'description': 'Single-player'}]
# 34998  [{'id': 2, 'description': 'Single-player'}, {'...
# 34999        [{'id': 2, 'description': 'Single-player'}]
#
#                                                   genres  \
# 0                 [{'id': '1', 'description': 'Action'}]
# 1                 [{'id': '1', 'description': 'Action'}]
# 2                 [{'id': '1', 'description': 'Action'}]
# 3                 [{'id': '1', 'description': 'Action'}]
# 4                 [{'id': '1', 'description': 'Action'}]
# ...                                                  ...
# 34995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34996  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34997  [{'id': '25', 'description': 'Adventure'}, {'i...
# 34998  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34999             [{'id': '4', 'description': 'Casual'}]
#
#                                              screenshots  \
# 0      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                  ...
# 34995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34996  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34997  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34998  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies    recommendations  \
# 0                                                    NaN  {'total': 118444}
# 1                                                    NaN    {'total': 4478}
# 2                                                    NaN    {'total': 3122}
# 3                                                    NaN    {'total': 1494}
# 4                                                    NaN   {'total': 11316}
# ...                                                  ...                ...
# 34995  [{'id': 256865353, 'name': 'Santhai Trailer', ...                NaN
# 34996  [{'id': 256868971, 'name': 'Virus At Home - Ga...                NaN
# 34997  [{'id': 256859762, 'name': 'Nelson 2 Trailer E...                NaN
# 34998  [{'id': 256861428, 'name': 'Stickit Trailer', ...                NaN
# 34999                                                NaN                NaN
#
#                                             achievements  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34995  {'total': 20, 'highlighted': [{'name': 'First ...
# 34996  {'total': 16, 'highlighted': [{'name': 'Nation...
# 34997                                                NaN
# 34998  {'total': 28, 'highlighted': [{'name': 'The Go...
# 34999                                                NaN
#
#                                          release_date  \
# 0       {'coming_soon': False, 'date': 'Nov 1, 2000'}
# 1       {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2       {'coming_soon': False, 'date': '1 May, 2003'}
# 3       {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4       {'coming_soon': False, 'date': '1 Nov, 1999'}
# ...                                               ...
# 34995  {'coming_soon': False, 'date': '13 Jan, 2022'}
# 34996   {'coming_soon': False, 'date': '7 Jan, 2022'}
# 34997  {'coming_soon': False, 'date': '28 Jan, 2022'}
# 34998  {'coming_soon': False, 'date': '12 Dec, 2021'}
# 34999  {'coming_soon': False, 'date': '21 Dec, 2021'}
#
#                                             support_info  \
# 0      {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                               {'url': '', 'email': ''}
# 2                               {'url': '', 'email': ''}
# 3                               {'url': '', 'email': ''}
# 4      {'url': 'https://help.steampowered.com', 'emai...
# ...                                                  ...
# 34995  {'url': 'https://www.hardworkerstudio.com/', '...
# 34996     {'url': '', 'email': 'svetaplanina@gmail.com'}
# 34997  {'url': 'https://www.manuelschenk.de/', 'email...
# 34998         {'url': '', 'email': 'symfonim@gmail.com'}
# 34999          {'url': '', 'email': 'sigyaad@gmail.com'}
#
#                                               background  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 34995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 34999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      content_descriptors    appid  \
# 0      {'ids': [2, 5], 'notes': 'Includes intense vio...       10
# 1      {'ids': [2, 5], 'notes': 'Includes intense vio...       20
# 2                             {'ids': [], 'notes': None}       30
# 3                             {'ids': [], 'notes': None}       40
# 4                             {'ids': [], 'notes': None}       50
# ...                                                  ...      ...
# 34995                         {'ids': [], 'notes': None}  1812930
# 34996                         {'ids': [], 'notes': None}  1814060
# 34997                         {'ids': [], 'notes': None}  1816650
# 34998                         {'ids': [], 'notes': None}  1828900
# 34999                         {'ids': [], 'notes': None}  1835060
#
#                                              name  \
# 0                                  Counter-Strike
# 1                           Team Fortress Classic
# 2                                   Day of Defeat
# 3                              Deathmatch Classic
# 4                       Half-Life: Opposing Force
# ...                                           ...
# 34995                                     Santhai
# 34996                               Virus at Home
# 34997  Nelson and the Magic Cauldron: The Journey
# 34998                                     Stickit
# 34999    Christmas Celebration With Sakuya Izayoi
#
#                                    developer           publisher  score_rank  \
# 0                                      Valve               Valve         NaN
# 1                                      Valve               Valve         NaN
# 2                                      Valve               Valve         NaN
# 3                                      Valve               Valve         NaN
# 4                           Gearbox Software               Valve         NaN
# ...                                      ...                 ...         ...
# 34995  Hardworker Studio, Rachan Neamprasert  Rachan Neamprasert         NaN
# 34996                          Bogdan Padjen       Bogdan Padjen         NaN
# 34997                    Manuel Schenk Games   Secret Item Games         NaN
# 34998                               Symfonim            Symfonim         NaN
# 34999                           Sigyaad Team        Sigyaad Team         NaN
#
#        positive  negative  userscore                    owners  \
# 0        192940      4936          0  10,000,000 .. 20,000,000
# 1          5409       895          0   5,000,000 .. 10,000,000
# 2          5000       555          0   5,000,000 .. 10,000,000
# 3          1852       412          0   5,000,000 .. 10,000,000
# 4         13243       661          0   5,000,000 .. 10,000,000
# ...         ...       ...        ...                       ...
# 34995        50         9          0               0 .. 20,000
# 34996        19         2          0               0 .. 20,000
# 34997        21         2          0               0 .. 20,000
# 34998        30         0          0               0 .. 20,000
# 34999        74         5          0               0 .. 20,000
#
#        average_forever  average_2weeks  median_forever  median_2weeks   price  \
# 0                11368             157             193             48   999.0
# 1                  217              58              14             58   499.0
# 2                  469               0              24              0   499.0
# 3                  256               0              13              0   499.0
# 4                  370               0             213              0   499.0
# ...                ...             ...             ...            ...     ...
# 34995                0               0               0              0   999.0
# 34996                0               0               0              0   199.0
# 34997                0               0               0              0  1499.0
# 34998                0               0               0              0   499.0
# 34999                0               0               0              0   399.0
#
#        initialprice  discount  \
# 0             999.0       0.0
# 1             499.0       0.0
# 2             499.0       0.0
# 3             499.0       0.0
# 4             499.0       0.0
# ...             ...       ...
# 34995         999.0       0.0
# 34996         199.0       0.0
# 34997        1499.0       0.0
# 34998         499.0       0.0
# 34999         399.0       0.0
#
#                                                languages  \
# 0      English, French, German, Italian, Spanish - Sp...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 34995                                      English, Thai
# 34996                                            English
# 34997                                    English, German
# 34998                                            English
# 34999                           English, Korean, Russian
#
#                                            genre    ccu  \
# 0                                         Action  17108
# 1                                         Action    114
# 2                                         Action    157
# 3                                         Action      5
# 4                                         Action    157
# ...                                          ...    ...
# 34995  Action, Adventure, Indie, RPG, Simulation      5
# 34996                   Action, Adventure, Indie      1
# 34997                          Adventure, Casual      1
# 34998                   Action, Adventure, Indie      1
# 34999                                     Casual      3
#
#                                                     tags
# 0      {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1      {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2      {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3      {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4      {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...
# ...                                                  ...
# 34995  {'Adventure': 439, 'RPG': 434, 'Action': 430, ...
# 34996  {'FPS': 91, 'Action': 85, 'Shooter': 82, 'Horr...
# 34997  {'Adventure': 94, 'Point & Click': 88, 'Puzzle...
# 34998  {'Difficult': 452, 'Precision Platformer': 441...
# 34999  {'Anime': 51, 'Casual': 47, 'Relaxing': 44, 'C...
#
# [35000 rows x 59 columns]

# %% [markdown]
# ## 2) Removing columns
# Besides finding the duplicate columns, there are other columns (like the descriptions) that offer no value to me, so I will clean them from the table to make it lighter.
#
# First I will look at the columns with descriptions, images and the like:

# %%
cols_to_drop = ['detailed_description', 'about_the_game', 'short_description', 'header_image', 'website', 'pc_requirements',
               'mac_requirements', 'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
               'packages', 'package_groups', 'screenshots', 'movies', 'achievements', 'support_info', 'background', 
                'reviews', 'content_descriptors', 'languages', 'categories']

# %%
data = data.drop(cols_to_drop, 1)
# Out:
# C:\Users\carlo\AppData\Local\Temp/ipykernel_19696/2397828251.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop(cols_to_drop, 1)

# %%
data.head()
# Out:
#    type                       name  steam_appid required_age is_free  \
# 0  game             Counter-Strike           10            0   False
# 1  game      Team Fortress Classic           20            0   False
# 2  game              Day of Defeat           30            0   False
# 3  game         Deathmatch Classic           40            0   False
# 4  game  Half-Life: Opposing Force           50            0   False
#
#   controller_support  dlc  fullgame  \
# 0                NaN  NaN       NaN
# 1                NaN  NaN       NaN
# 2                NaN  NaN       NaN
# 3                NaN  NaN       NaN
# 4                NaN  NaN       NaN
#
#                                  supported_languages            developers  \
# 0  English<strong>*</strong>, French<strong>*</st...             ['Valve']
# 1  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 2  English, French, German, Italian, Spanish - Spain             ['Valve']
# 3  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 4                    English, French, German, Korean  ['Gearbox Software']
#
#   publishers demos                                     price_overview  \
# 0  ['Valve']   NaN  {'currency': 'USD', 'initial': 999, 'final': 9...
# 1  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 2  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 3  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
# 4  ['Valve']   NaN  {'currency': 'EUR', 'initial': 399, 'final': 3...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...
# 1                                                NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...
# 3                                                NaN
# 4                                                NaN
#
#                                    genres    recommendations  \
# 0  [{'id': '1', 'description': 'Action'}]  {'total': 118444}
# 1  [{'id': '1', 'description': 'Action'}]    {'total': 4478}
# 2  [{'id': '1', 'description': 'Action'}]    {'total': 3122}
# 3  [{'id': '1', 'description': 'Action'}]    {'total': 1494}
# 4  [{'id': '1', 'description': 'Action'}]   {'total': 11316}
#
#                                     release_date  appid  \
# 0  {'coming_soon': False, 'date': 'Nov 1, 2000'}     10
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}     20
# 2  {'coming_soon': False, 'date': '1 May, 2003'}     30
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}     40
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}     50
#
#                         name         developer publisher  score_rank  \
# 0             Counter-Strike             Valve     Valve         NaN
# 1      Team Fortress Classic             Valve     Valve         NaN
# 2              Day of Defeat             Valve     Valve         NaN
# 3         Deathmatch Classic             Valve     Valve         NaN
# 4  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    192940      4936          0  10,000,000 .. 20,000,000            11368
# 1      5409       895          0   5,000,000 .. 10,000,000              217
# 2      5000       555          0   5,000,000 .. 10,000,000              469
# 3      1852       412          0   5,000,000 .. 10,000,000              256
# 4     13243       661          0   5,000,000 .. 10,000,000              370
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0             157             193             48  999.0         999.0
# 1              58              14             58  499.0         499.0
# 2               0              24              0  499.0         499.0
# 3               0              13              0  499.0         499.0
# 4               0             213              0  499.0         499.0
#
#    discount   genre    ccu                                               tags
# 0       0.0  Action  17108  {'Action': 5379, 'FPS': 4801, 'Multiplayer': 3...
# 1       0.0  Action    114  {'Action': 745, 'FPS': 306, 'Multiplayer': 257...
# 2       0.0  Action    157  {'FPS': 786, 'World War II': 247, 'Multiplayer...
# 3       0.0  Action      5  {'Action': 629, 'FPS': 139, 'Classic': 107, 'M...
# 4       0.0  Action    157  {'FPS': 880, 'Action': 321, 'Classic': 250, 'S...

# %% [markdown]
# Now I will check the duplicates:

# %%
dupes_to_drop = ['name', 'steam_appid', 'supported_languages','developer', 'publisher', 'genre']
data = data.drop(dupes_to_drop, 1)
# Out:
# C:\Users\carlo\AppData\Local\Temp/ipykernel_19696/1596603079.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop(dupes_to_drop, 1)

# %% [markdown]
# As there are two columns with the name `name`, both are dropped. As they work as identifiers, their use was limited anyway.

# %%
data.shape
# Out:
# (35000, 30)

# %% [markdown]
# ## 3) Analyzing rows
# I want to check the existence of duplicates:

# %%
data.duplicated(keep='first').value_counts()
# Out:
# False    33703
# True      1297
# dtype: int64

# %% [markdown]
# As there are duplicates, I will drop those rows.

# %%
data = data.drop_duplicates(keep='first') #keep='first' assures that the first appearance is kept

# %%
data.duplicated(keep='first').value_counts()
# Out:
# False    33703
# dtype: int64

# %% [markdown]
# ## 4) Analyzing columns
# At first glance, I can already see there are various fields with NaN values, and other fields with lists or dictionaries that should be transformed into individual columns.
#
# ### NaNs

# %%
data.isna().sum()
# Out:
# type                     65
# required_age             65
# is_free                  65
# controller_support    26301
# dlc                   26571
# fullgame              33703
# developers              173
# publishers               65
# demos                 31002
# price_overview         6217
# platforms                65
# metacritic            30135
# genres                  134
# recommendations       22799
# release_date             65
# appid                     0
# score_rank            33678
# positive                  0
# negative                  0
# userscore                 0
# owners                    0
# average_forever           0
# average_2weeks            0
# median_forever            0
# median_2weeks             0
# price                     4
# initialprice              4
# discount                  4
# ccu                       0
# tags                      0
# dtype: int64

# %% [markdown]
# I see that (in the sample version of the dataset) the amount of NaN values in the columns `fullgame` and `score_rank` are too high to keep them.

# %%
data = data.drop(['fullgame', 'score_rank'], axis=1)

# %% [markdown]
# The column `type` works as a flag to check if the row has actual data or is an empty row: if it is NaN, the rest of the row will also be empty besides the appid.

# %%
data[data['type'].isna()]
# Out:
#       type required_age is_free controller_support  dlc developers publishers  \
# 1043   NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 1063   NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 1066   NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 1071   NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 1164   NaN          NaN     NaN                NaN  NaN        NaN        NaN
# ...    ...          ...     ...                ...  ...        ...        ...
# 30001  NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 31000  NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 31127  NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 31209  NaN          NaN     NaN                NaN  NaN        NaN        NaN
# 31217  NaN          NaN     NaN                NaN  NaN        NaN        NaN
#
#       demos price_overview platforms metacritic genres recommendations  \
# 1043    NaN            NaN       NaN        NaN    NaN             NaN
# 1063    NaN            NaN       NaN        NaN    NaN             NaN
# 1066    NaN            NaN       NaN        NaN    NaN             NaN
# 1071    NaN            NaN       NaN        NaN    NaN             NaN
# 1164    NaN            NaN       NaN        NaN    NaN             NaN
# ...     ...            ...       ...        ...    ...             ...
# 30001   NaN            NaN       NaN        NaN    NaN             NaN
# 31000   NaN            NaN       NaN        NaN    NaN             NaN
# 31127   NaN            NaN       NaN        NaN    NaN             NaN
# 31209   NaN            NaN       NaN        NaN    NaN             NaN
# 31217   NaN            NaN       NaN        NaN    NaN             NaN
#
#       release_date   appid  positive  negative  userscore  \
# 1043           NaN   11610      1625       592          0
# 1063           NaN   21130      5171       835          0
# 1066           NaN   22490     46753      2153         95
# 1071           NaN   24720      4486       639          0
# 1164           NaN  212200      2454       818          0
# ...            ...     ...       ...       ...        ...
# 30001          NaN   33720        12         1          0
# 31000          NaN  226760         0         0          0
# 31127          NaN  560920         1         2          0
# 31209          NaN  700740        41        26          0
# 31217          NaN  710130         0         0          0
#
#                      owners  average_forever  average_2weeks  median_forever  \
# 1043   500,000 .. 1,000,000             1199               0             812
# 1063   500,000 .. 1,000,000              473               0             219
# 1066   500,000 .. 1,000,000             4510            1355            2075
# 1071   500,000 .. 1,000,000             2510             324             656
# 1164   500,000 .. 1,000,000             5824               0            8995
# ...                     ...              ...             ...             ...
# 30001           0 .. 20,000                0               0               0
# 31000           0 .. 20,000                0               0               0
# 31127           0 .. 20,000                0               0               0
# 31209           0 .. 20,000                3               0               3
# 31217           0 .. 20,000              611               0             611
#
#        median_2weeks   price  initialprice  discount   ccu  \
# 1043               0     0.0           0.0       0.0    39
# 1063               0  1999.0        1999.0       0.0   472
# 1066            1355   999.0         999.0       0.0  1556
# 1071             324   499.0        1999.0      75.0   336
# 1164               0     0.0           0.0       0.0   417
# ...              ...     ...           ...       ...   ...
# 30001              0   699.0         699.0       0.0     0
# 31000              0     0.0           0.0       0.0     1
# 31127              0     0.0           0.0       0.0     0
# 31209              0   999.0         999.0       0.0     1
# 31217              0     0.0           0.0       0.0     1
#
#                                                     tags
# 1043   {'Free to Play': 116, 'Action': 87, 'RPG': 82,...
# 1063   {'LEGO': 180, 'Adventure': 122, 'Local Co-Op':...
# 1066   {'Open World': 2453, 'RPG': 2327, 'Post-apocal...
# 1071   {'Simulation': 171, 'Action': 131, 'Space': 12...
# 1164   {'Free to Play': 188, 'Massively Multiplayer':...
# ...                                                  ...
# 30001                   {'Simulation': 41, 'Casual': 40}
# 31000                                                 []
# 31127  {'Video Production': 23, 'Utilities': 14, 'VR'...
# 31209  {'Action': 24, 'Arcade': 14, "Beat 'em up": 14...
# 31217                                                 []
#
# [65 rows x 28 columns]

# %%
data.dropna(subset = ["type"], inplace=True)

# %%
data.isna().sum()
# Out:
# type                      0
# required_age              0
# is_free                   0
# controller_support    26236
# dlc                   26506
# developers              108
# publishers                0
# demos                 30937
# price_overview         6152
# platforms                 0
# metacritic            30070
# genres                   69
# recommendations       22734
# release_date              0
# appid                     0
# positive                  0
# negative                  0
# userscore                 0
# owners                    0
# average_forever           0
# average_2weeks            0
# median_forever            0
# median_2weeks             0
# price                     0
# initialprice              0
# discount                  0
# ccu                       0
# tags                      0
# dtype: int64

# %% [markdown]
# Some of the columns with NaNs can have those values changed into Unknown, but those columns may have the above mentioned lists and dictionaries.
# I will transform those values as stated.

# %%
data['developers'] = data['developers'].fillna('Unknown')
data['publishers'] = data['publishers'].fillna('Unknown')

# %% [markdown]
# Further fillings require studying the values on those columns:

# %%
data['controller_support'].value_counts(dropna=False)
# Out:
# NaN     26236
# full     7402
# Name: controller_support, dtype: int64

# %% [markdown]
# This column may pressent issues when using the whole set, but the idea is to make it boolean (0 or 1).

# %%
data['controller_support'] = data['controller_support'].fillna(0)
data['controller_support'] = np.where(data['controller_support'] == 'full', 1, 0)

# %%
data['controller_support'].value_counts(dropna=False)
# Out:
# 0    26236
# 1     7402
# Name: controller_support, dtype: int64

# %%
data['dlc'].value_counts(dropna=False)
# Out:
# NaN                            26506
# [1477350]                          3
# [1511180]                          2
# [1310430]                          2
# [640940]                           2
#                                ...
# [1249280, 1289400, 1464740]        1
# [1022120, 1055880]                 1
# [1805541]                          1
# [1058300]                          1
# [1753770]                          1
# Name: dlc, Length: 7110, dtype: int64

# %% [markdown]
# This column represents whether the game has any extra downloadable content, and links it to its appid. I just need to know if there is, so I will change it to boolean as well.

# %%
data['dlc'] = data['dlc'].fillna(0)
data['dlc'] = np.where(data['dlc'] == 0, 0, 1)

# %%
data['dlc'].value_counts(dropna=False)
# Out:
# 0    26506
# 1     7132
# Name: dlc, dtype: int64

# %%
data['demos'].value_counts(dropna=False)
# Out:
# NaN                                                  30937
# [{'appid': 47760, 'description': ''}]                    2
# [{'appid': 249970, 'description': 'Demo'}]               2
# [{'appid': 612970, 'description': ''}]                   2
# [{'appid': 353020, 'description': 'Try it now!'}]        2
#                                                      ...
# [{'appid': 1378300, 'description': ''}]                  1
# [{'appid': 1386120, 'description': 'Free'}]              1
# [{'appid': 1899420, 'description': ''}]                  1
# [{'appid': 1450110, 'description': 'Free'}]              1
# [{'appid': 1795280, 'description': ''}]                  1
# Name: demos, Length: 2691, dtype: int64

# %% [markdown]
# As above, for this column I only want to know if there is a demo associated to the game, not the ID of said demo, so I will do the same process.

# %%
data['demos'] = data['demos'].fillna(0)
data['demos'] = np.where(data['demos'] == 0, 0, 1)

# %%
data['demos'].value_counts(dropna=False)
# Out:
# 0    30937
# 1     2701
# Name: demos, dtype: int64

# %%
data['price_overview'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                           6152
# {'currency': 'EUR', 'initial': 79, 'final': 79, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '0,79€'}                                                                                                                   2343
# {'currency': 'EUR', 'initial': 399, 'final': 399, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '3,99€'}                                                                                                                 2256
# {'currency': 'EUR', 'initial': 999, 'final': 999, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '9,99€'}                                                                                                                 2091
# {'currency': 'EUR', 'initial': 499, 'final': 499, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '4,99€'}                                                                                                                 1841
#                                                                                                                                                                                                                                               ...
# {'currency': 'EUR', 'initial': 99, 'final': 50, 'discount_percent': 49, 'initial_formatted': '0,99€', 'final_formatted': '0,50€'}                                                                                                                1
# {'currency': 'EUR', 'initial': 699, 'final': 244, 'discount_percent': 65, 'initial_formatted': '6,99€', 'final_formatted': '2,44€'}                                                                                                              1
# {'currency': 'EUR', 'initial': 499, 'final': 119, 'discount_percent': 76, 'initial_formatted': '4,99€', 'final_formatted': '1,19€'}                                                                                                              1
# {'currency': 'EUR', 'initial': 819, 'final': 819, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '8,19€', 'recurring_sub': 264676, 'recurring_sub_desc': '7,99€ at checkout, auto-renewed every 1 month(s) at 6,59€.'}       1
# {'currency': 'EUR', 'initial': 1159, 'final': 695, 'discount_percent': 40, 'initial_formatted': '11,59€', 'final_formatted': '6,95€'}                                                                                                            1
# Name: price_overview, Length: 1031, dtype: int64

# %% [markdown]
# This is too complex to handle at the moment, but I may need it later, so I will save it in a different value.

# %%
price_df = data['price_overview']
data = data.drop('price_overview', axis=1)

# %%
data['metacritic'].value_counts(dropna=False)
# Out:
# NaN                                                                                                              30070
# {'score': 88, 'url': 'https://www.metacritic.com/game/pc/fear?ftag=MCD-06-10aaa1f'}                                  3
# {'score': 75, 'url': 'https://www.metacritic.com/game/pc/sin-episodes-emergence?ftag=MCD-06-10aaa1f'}                2
# {'score': 80, 'url': 'https://www.metacritic.com/game/pc/guns-gore-cannoli-2?ftag=MCD-06-10aaa1f'}                   2
# {'score': 68, 'url': 'https://www.metacritic.com/game/pc/seeking-dawn?ftag=MCD-06-10aaa1f'}                          2
#                                                                                                                  ...
# {'score': 82, 'url': 'https://www.metacritic.com/game/pc/the-banner-saga-2?ftag=MCD-06-10aaa1f'}                     1
# {'score': 70, 'url': 'https://www.metacritic.com/game/pc/nosferatu-the-wrath-of-malachi?ftag=MCD-06-10aaa1f'}        1
# {'score': 67, 'url': 'https://www.metacritic.com/game/pc/incoming-forces?ftag=MCD-06-10aaa1f'}                       1
# {'score': 80, 'url': 'https://www.metacritic.com/game/pc/tooth-and-tail?ftag=MCD-06-10aaa1f'}                        1
# {'score': 78, 'url': 'https://www.metacritic.com/game/pc/shut-in?ftag=MCD-06-10aaa1f'}                               1
# Name: metacritic, Length: 3542, dtype: int64

# %% [markdown]
# **There are too many empty values to keep this column**
# Luckily, there are similar columns in the form of `positive` `negative` and `recommendations`, so this one is not that important.

# %%
data = data.drop(['metacritic'], axis=1)

# %%
data['genres'].value_counts(dropna=False)
# Out:
# [{'id': '1', 'description': 'Action'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                                                               2019
# [{'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                                                               1592
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Adventure'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                     1563
# [{'id': '25', 'description': 'Adventure'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                                                           1494
# [{'id': '1', 'description': 'Action'}]                                                                                                                                                                                                                                                                                                                                                     1153
#                                                                                                                                                                                                                                                                                                                                                                                            ...
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Aventure'}, {'id': '23', 'description': 'Indépendant'}]                                                                                                                                                                                                                                                                   1
# [{'id': '73', 'description': 'Violent'}, {'id': '25', 'description': 'Adventure'}, {'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}, {'id': '28', 'description': 'Simulation'}]                                                                                                                                                                                     1
# [{'id': '73', 'description': 'Violent'}, {'id': '1', 'description': 'Action'}, {'id': '4', 'description': 'Casual'}, {'id': '37', 'description': 'Free to Play'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                       1
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Adventure'}, {'id': '37', 'description': 'Free to Play'}, {'id': '23', 'description': 'Indie'}, {'id': '29', 'description': 'Massively Multiplayer'}, {'id': '9', 'description': 'Racing'}, {'id': '3', 'description': 'RPG'}, {'id': '2', 'description': 'Strategy'}, {'id': '70', 'description': 'Early Access'}]       1
# [{'id': '1', 'description': 'Action'}, {'id': '23', 'description': 'Indie'}, {'id': '29', 'description': 'Massively Multiplayer'}, {'id': '9', 'description': 'Racing'}, {'id': '70', 'description': 'Early Access'}]                                                                                                                                                                         1
# Name: genres, Length: 1720, dtype: int64

# %% [markdown]
# I want to keep as much information from this column as possible, even though it is the most likely to be dropped due to complexity. For that, I will create a fallback dictionary with an Unknown genre and assign it to the NaN values. Later, that Unknown will also be dropped, when the processing of this column finishes.

# %%
unknown_genre = "[{'id': '0', 'description': 'Unknown'}]"
data['genres'] = data['genres'].fillna(unknown_genre)

# %%
data['recommendations'].value_counts(dropna=False)
# Out:
# NaN                 22734
# {'total': 108}         51
# {'total': 127}         46
# {'total': 105}         45
# {'total': 102}         44
#                     ...
# {'total': 7344}         1
# {'total': 10165}        1
# {'total': 7382}         1
# {'total': 6467}         1
# {'total': 1268}         1
# Name: recommendations, Length: 3683, dtype: int64

# %% [markdown]
# **Too many empty values**
# I will need this information, so I will assign {'total': 0} as value. (I don't trust this result yet)

# %%
data['recommendations'] = data['recommendations'].fillna("{'total': 0}")

# %%
data['recommendations'].value_counts(dropna=False)
# Out:
# {'total': 0}        22734
# {'total': 108}         51
# {'total': 127}         46
# {'total': 105}         45
# {'total': 102}         44
#                     ...
# {'total': 7344}         1
# {'total': 10165}        1
# {'total': 7382}         1
# {'total': 6467}         1
# {'total': 1268}         1
# Name: recommendations, Length: 3683, dtype: int64

# %% [markdown]
# After all this cleaning, this is the result:

# %%
data.isna().sum()
# Out:
# type                  0
# required_age          0
# is_free               0
# controller_support    0
# dlc                   0
# developers            0
# publishers            0
# demos                 0
# platforms             0
# genres                0
# recommendations       0
# release_date          0
# appid                 0
# positive              0
# negative              0
# userscore             0
# owners                0
# average_forever       0
# average_2weeks        0
# median_forever        0
# median_2weeks         0
# price                 0
# initialprice          0
# discount              0
# ccu                   0
# tags                  0
# dtype: int64

# %%
def number_uniques(table):
    for col in table.columns:
        n = len(pd.unique(table[col]))
        
        print('Column', col, 'has', n, 'different values.')

# %%
number_uniques(data)
# Out:
# Column type has 2 different values.
# Column required_age has 28 different values.
# Column is_free has 2 different values.
# Column controller_support has 2 different values.
# Column dlc has 2 different values.
# Column developers has 21620 different values.
# Column publishers has 17999 different values.
# Column demos has 2 different values.
# Column platforms has 7 different values.
# Column genres has 1720 different values.
# Column recommendations has 3683 different values.
# Column release_date has 4082 different values.
# Column appid has 33571 different values.
# Column positive has 4265 different values.
# Column negative has 2125 different values.
# Column userscore has 18 different values.
# Column owners has 13 different values.
# Column average_forever has 2007 different values.
# Column average_2weeks has 574 different values.
# Column median_forever has 1813 different values.
# Column median_2weeks has 567 different values.
# Column price has 260 different values.
# Column initialprice has 140 different values.
# Column discount has 52 different values.
# Column ccu has 1194 different values.
# Column tags has 32523 different values.

# %% [markdown]
# ## 5) Saving the results
# ### CSV file

# %%
steam_clean_df = data.copy()
steam_clean_df.to_csv('data/steam_clean.csv', index=False)

# %% [markdown]
# ### Database

# %%
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/steam'
engine = create_engine(connection_string)

# %% [markdown]
# Before writing to the database, I need to create said database in the workbench.

# %%
steam_clean_df.to_sql('steam', con=engine)
